# %%
# %run q2_parser_transitions.py
# Out:
# SHIFT test passed!
# LEFT-ARC test passed!
# RIGHT-ARC test passed!
# parse test passed!
# minibatch_parse test passed!

# %%
# %run q2_initialization.py
# Out:
# Running basic tests...
# Basic (non-exhaustive) Xavier initialization tests pass

# %%
# %run q2_parser_model.py
# Out:
# ...
# INITIALIZING
# ...
# Loading data... took 2.49 seconds
# Building parser... took 1.53 seconds
# Loading pretrained embeddings... took 2.69 seconds
# Vectorizing data... took 1.70 seconds
# Preprocessing training data...
#  - ETA: 9s
# 1892336 1700 2416
# Building model... took 0.34 seconds
#
# ...
# TRAINING
# ...
# Epoch 1 out of 10
# 924/924 [==============================] - 40s - train loss: 0.7076
# Evaluating on dev set 20319.0 40117.0
# - dev UAS: 50.65
# 0.506493506494 0
# New best dev UAS! Saving model in ./data/weights/parser.weights
#
# Epoch 2 out of 10
#  - ETA: 8s - train loss: 0.4277
# Evaluating on dev set 23202.0 40117.0
# - dev UAS: 57.84
# 0.578358301967 0.506493506494
# New best dev UAS! Saving model in ./data/weights/parser.weights
#
# Epoch 3 out of 10
# 924/924 [==============================] - 37s - train loss: 0.3410
# Evaluating on dev set 24901.0 40117.0
# - dev UAS: 62.07
# 0.620709424932 0.578358301967
# New best dev UAS! Saving model in ./data/weights/parser.weights
#
# ...
